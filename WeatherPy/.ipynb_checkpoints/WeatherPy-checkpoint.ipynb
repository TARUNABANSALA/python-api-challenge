# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
! pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\panka\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\panka\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
from pprint import pprint

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 616

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# base_url = 'https://api.openweathermap.org/data/2.5/weather?'
# units = "metric"
# # Build partial query URL
# parameter_1 = 'q='
# parameter_2 = '&appid='
# parameter_3 = '&units='
# cities = [london, delhi, moscow]
# city_data = []
# for city in cities:
#     combined_url = f"{base_url}{parameter_1}{city}{parameter_2}{weather_api_key}"
#     response = requests.get(combined_url).json()
#     city_data.append(response['coord']['lat'])
#     temp.append(response['main']['temp'])

# %%
# Set the API base URL
base_url = 'https://api.openweathermap.org/data/2.5/weather?'
units = "metric"
# Build partial query URL
parameter_1 = 'q='
parameter_2 = '&appid='
parameter_3 = '&units='
# Define an empty list to fetch the weather data for each city
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):   
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = f"{base_url}{parameter_1}{city}{parameter_2}{weather_api_key}{parameter_3}{units}"
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | semporna
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | lavrentiya
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | ahipara
# Processing Record 9 of Set 1 | nelson bay
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | ellensburg
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | katherine
# Processing Record 16 of Set 1 | mgandu
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | komsomolskiy
# Processing Record 19 of Set 1 | faanui
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | ayan
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | batemans bay
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | novoseleznevo
# Processing Record 28 of Set 1 | punta de bombon
# Processing Record 29 of Set 1 | hofn
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | bengkulu
# Processing Record 32 of Set 1 | deputatskiy
# Processing Record 33 of Set 1 | zhangye
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | asau
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | camana
# Processing Record 42 of Set 1 | snasa
# Processing Record 43 of Set 1 | okhotsk
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | palmer
# Processing Record 46 of Set 1 | bahir dar
# Processing Record 47 of Set 1 | xixiang
# Processing Record 48 of Set 1 | caruray
# Processing Record 49 of Set 1 | susanville
# Processing Record 50 of Set 1 | dulce nombre de culmi
# Processing Record 0 of Set 2 | rikitea
# Processing Record 1 of Set 2 | braslav
# City not found. Skipping...
# Processing Record 2 of Set 2 | mayor pablo lagerenza
# Processing Record 3 of Set 2 | bud
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | turayf
# Processing Record 7 of Set 2 | cascais
# Processing Record 8 of Set 2 | bubaque
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | geraldton
# Processing Record 11 of Set 2 | tahoua
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | henties bay
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | ancud
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | srednyaya akhtuba
# Processing Record 18 of Set 2 | san andres
# Processing Record 19 of Set 2 | namibe
# Processing Record 20 of Set 2 | cazaje
# City not found. Skipping...
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | cabo san lucas
# Processing Record 24 of Set 2 | mount gambier
# Processing Record 25 of Set 2 | bambous virieux
# Processing Record 26 of Set 2 | alofi
# Processing Record 27 of Set 2 | azogues
# Processing Record 28 of Set 2 | cananeia
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | saint-ambroise
# Processing Record 31 of Set 2 | dali
# Processing Record 32 of Set 2 | aban
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | sola
# Processing Record 35 of Set 2 | acarau
# Processing Record 36 of Set 2 | vila velha
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | acapulco
# Processing Record 39 of Set 2 | nhulunbuy
# Processing Record 40 of Set 2 | dariba
# Processing Record 41 of Set 2 | maunabo
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | prince albert
# Processing Record 44 of Set 2 | nome
# Processing Record 45 of Set 2 | omboue
# Processing Record 46 of Set 2 | whitehorse
# Processing Record 47 of Set 2 | moree
# Processing Record 48 of Set 2 | luganville
# Processing Record 49 of Set 2 | khatanga
# Processing Record 0 of Set 3 | roma
# Processing Record 1 of Set 3 | san-pedro
# Processing Record 2 of Set 3 | saint augustine
# Processing Record 3 of Set 3 | albury
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | londiani
# Processing Record 7 of Set 3 | chokurdakh
# Processing Record 8 of Set 3 | mmathubudukwane
# Processing Record 9 of Set 3 | aksu
# Processing Record 10 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 16 of Set 3 | slave lake
# Processing Record 17 of Set 3 | pangnirtung
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | te anau
# Processing Record 21 of Set 3 | berdigestyakh
# Processing Record 22 of Set 3 | pahrump
# Processing Record 23 of Set 3 | flin flon
# Processing Record 24 of Set 3 | nicoya
# Processing Record 25 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 3 | iskitim
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | terrace
# Processing Record 29 of Set 3 | goderich
# Processing Record 30 of Set 3 | matara
# Processing Record 31 of Set 3 | gorokhovets
# Processing Record 32 of Set 3 | ishigaki
# Processing Record 33 of Set 3 | lac du bonnet
# Processing Record 34 of Set 3 | inhambane
# Processing Record 35 of Set 3 | mar del plata
# Processing Record 36 of Set 3 | praia da vitoria
# Processing Record 37 of Set 3 | karamken
# City not found. Skipping...
# Processing Record 38 of Set 3 | kathmandu
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | eureka
# Processing Record 41 of Set 3 | port blair
# Processing Record 42 of Set 3 | carmen
# Processing Record 43 of Set 3 | nortelandia
# Processing Record 44 of Set 3 | lincoln
# Processing Record 45 of Set 3 | ostrovnoy
# Processing Record 46 of Set 3 | talnakh
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | doha
# Processing Record 49 of Set 3 | milyutinskaya
# Processing Record 0 of Set 4 | ilhabela
# Processing Record 1 of Set 4 | bara
# Processing Record 2 of Set 4 | mnogovershinnyy
# Processing Record 3 of Set 4 | santander
# Processing Record 4 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 4 | roebourne
# Processing Record 6 of Set 4 | keflavik
# Processing Record 7 of Set 4 | los llanos de aridane
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | naze
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 4 | sompeta
# Processing Record 13 of Set 4 | martinsville
# Processing Record 14 of Set 4 | merauke
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | flinders
# Processing Record 17 of Set 4 | caravelas
# Processing Record 18 of Set 4 | montecorvino rovella
# Processing Record 19 of Set 4 | dikson
# Processing Record 20 of Set 4 | pacific grove
# Processing Record 21 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 4 | havre-saint-pierre
# Processing Record 23 of Set 4 | saldanha
# Processing Record 24 of Set 4 | egvekinot
# Processing Record 25 of Set 4 | mopti
# Processing Record 26 of Set 4 | muravlenko
# Processing Record 27 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 4 | sioux lookout
# Processing Record 29 of Set 4 | oussouye
# Processing Record 30 of Set 4 | haimen
# Processing Record 31 of Set 4 | seymchan
# Processing Record 32 of Set 4 | ulundi
# Processing Record 33 of Set 4 | davidson
# Processing Record 34 of Set 4 | sao jose da coroa grande
# Processing Record 35 of Set 4 | yellowknife
# Processing Record 36 of Set 4 | paidha
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | hilo
# Processing Record 40 of Set 4 | rocky mountain house
# Processing Record 41 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 4 | ystad
# Processing Record 43 of Set 4 | coffs harbour
# Processing Record 44 of Set 4 | isangel
# Processing Record 45 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 4 | srirampur
# Processing Record 47 of Set 4 | hermanus
# Processing Record 48 of Set 4 | kailua
# Processing Record 49 of Set 4 | ponnani
# Processing Record 0 of Set 5 | morros
# Processing Record 1 of Set 5 | lithakia
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | saint george
# Processing Record 4 of Set 5 | provideniya
# Processing Record 5 of Set 5 | yorkton
# Processing Record 6 of Set 5 | shimoda
# Processing Record 7 of Set 5 | port hardy
# Processing Record 8 of Set 5 | labuhan
# Processing Record 9 of Set 5 | san patricio
# Processing Record 10 of Set 5 | mhlume
# Processing Record 11 of Set 5 | smoky lake
# Processing Record 12 of Set 5 | nikolskoye
# Processing Record 13 of Set 5 | hualmay
# Processing Record 14 of Set 5 | clonakilty
# Processing Record 15 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 5 | oriximina
# Processing Record 17 of Set 5 | christchurch
# Processing Record 18 of Set 5 | beringovskiy
# Processing Record 19 of Set 5 | ozernovskiy
# Processing Record 20 of Set 5 | saint-georges
# Processing Record 21 of Set 5 | grindavik
# Processing Record 22 of Set 5 | sur
# Processing Record 23 of Set 5 | beausejour
# Processing Record 24 of Set 5 | hasaki
# Processing Record 25 of Set 5 | muscat
# Processing Record 26 of Set 5 | alice springs
# Processing Record 27 of Set 5 | glenwood springs
# Processing Record 28 of Set 5 | tsumeb
# Processing Record 29 of Set 5 | chernushka
# Processing Record 30 of Set 5 | unna
# Processing Record 31 of Set 5 | krivosheino
# Processing Record 32 of Set 5 | panaba
# Processing Record 33 of Set 5 | dong hoi
# Processing Record 34 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 5 | east london
# Processing Record 36 of Set 5 | hammerfest
# Processing Record 37 of Set 5 | shache
# Processing Record 38 of Set 5 | abbeville
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 | sitka
# Processing Record 41 of Set 5 | mareeba
# Processing Record 42 of Set 5 | kruisfontein
# Processing Record 43 of Set 5 | huaihua
# Processing Record 44 of Set 5 | tornio
# Processing Record 45 of Set 5 | amapa
# Processing Record 46 of Set 5 | toma
# Processing Record 47 of Set 5 | khandyga
# Processing Record 48 of Set 5 | tenenkou
# Processing Record 49 of Set 5 | souillac
# Processing Record 0 of Set 6 | solnechnyy
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | bethel
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | mocuba
# Processing Record 5 of Set 6 | robertsport
# Processing Record 6 of Set 6 | georgetown
# Processing Record 7 of Set 6 | axim
# Processing Record 8 of Set 6 | amahai
# Processing Record 9 of Set 6 | denpasar
# Processing Record 10 of Set 6 | januaria
# Processing Record 11 of Set 6 | huarmey
# Processing Record 12 of Set 6 | torbay
# Processing Record 13 of Set 6 | novopokrovka
# Processing Record 14 of Set 6 | yinchuan
# Processing Record 15 of Set 6 | marienburg
# Processing Record 16 of Set 6 | krasnoselkup
# Processing Record 17 of Set 6 | oistins
# Processing Record 18 of Set 6 | dingle
# Processing Record 19 of Set 6 | soe
# Processing Record 20 of Set 6 | cidreira
# Processing Record 21 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 6 | half moon bay
# Processing Record 23 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | margate
# Processing Record 25 of Set 6 | ketchikan
# Processing Record 26 of Set 6 | lima
# Processing Record 27 of Set 6 | yelatma
# Processing Record 28 of Set 6 | leningradskiy
# Processing Record 29 of Set 6 | zhoucheng
# Processing Record 30 of Set 6 | tilichiki
# Processing Record 31 of Set 6 | concarneau
# Processing Record 32 of Set 6 | port elizabeth
# Processing Record 33 of Set 6 | portpatrick
# City not found. Skipping...
# Processing Record 34 of Set 6 | iquitos
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | kirakira
# Processing Record 37 of Set 6 | sao filipe
# Processing Record 38 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 39 of Set 6 | sao sebastiao
# Processing Record 40 of Set 6 | mamallapuram
# Processing Record 41 of Set 6 | gornopravdinsk
# Processing Record 42 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 6 | bacolod
# Processing Record 44 of Set 6 | paytug
# City not found. Skipping...
# Processing Record 45 of Set 6 | portland
# Processing Record 46 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 6 | along
# Processing Record 48 of Set 6 | kudahuvadhoo
# Processing Record 49 of Set 6 | bangassou
# Processing Record 0 of Set 7 | westport
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | saint-pierre
# Processing Record 3 of Set 7 | tessalit
# Processing Record 4 of Set 7 | sobolevo
# Processing Record 5 of Set 7 | sept-iles
# Processing Record 6 of Set 7 | kushmurun
# Processing Record 7 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 7 | paka
# Processing Record 9 of Set 7 | fonte boa
# Processing Record 10 of Set 7 | lorengau
# Processing Record 11 of Set 7 | marzuq
# Processing Record 12 of Set 7 | amga
# Processing Record 13 of Set 7 | at-bashi
# Processing Record 14 of Set 7 | port hedland
# Processing Record 15 of Set 7 | saskylakh
# Processing Record 16 of Set 7 | basco
# Processing Record 17 of Set 7 | clyde river
# Processing Record 18 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 7 | nemuro
# Processing Record 20 of Set 7 | dudinka
# Processing Record 21 of Set 7 | victor harbor
# Processing Record 22 of Set 7 | bharatpur
# Processing Record 23 of Set 7 | savinka
# Processing Record 24 of Set 7 | shitanjing
# Processing Record 25 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 7 | woodward
# Processing Record 27 of Set 7 | krugersdorp
# Processing Record 28 of Set 7 | najran
# Processing Record 29 of Set 7 | nouadhibou
# Processing Record 30 of Set 7 | clarksdale
# Processing Record 31 of Set 7 | zyryanka
# Processing Record 32 of Set 7 | broken hill
# Processing Record 33 of Set 7 | kampong thum
# Processing Record 34 of Set 7 | cangzhou
# Processing Record 35 of Set 7 | varhaug
# Processing Record 36 of Set 7 | aranos
# Processing Record 37 of Set 7 | locri
# Processing Record 38 of Set 7 | saint combs
# City not found. Skipping...
# Processing Record 39 of Set 7 | taoudenni
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | kitaibaraki
# Processing Record 42 of Set 7 | svetlyy
# Processing Record 43 of Set 7 | maceio
# Processing Record 44 of Set 7 | raudeberg
# Processing Record 45 of Set 7 | tura
# Processing Record 46 of Set 7 | necochea
# Processing Record 47 of Set 7 | viedma
# Processing Record 48 of Set 7 | yangambi
# Processing Record 49 of Set 7 | maridi
# Processing Record 0 of Set 8 | bathsheba
# Processing Record 1 of Set 8 | baripada
# Processing Record 2 of Set 8 | naples
# Processing Record 3 of Set 8 | san roque
# Processing Record 4 of Set 8 | sorong
# Processing Record 5 of Set 8 | zhigansk
# Processing Record 6 of Set 8 | podor
# Processing Record 7 of Set 8 | karratha
# Processing Record 8 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 8 | dunedin
# Processing Record 10 of Set 8 | port lincoln
# Processing Record 11 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 8 | santiago de chuco
# Processing Record 14 of Set 8 | griffith
# Processing Record 15 of Set 8 | keti bandar
# Processing Record 16 of Set 8 | luwuk
# Processing Record 17 of Set 8 | martinsburg
# Processing Record 18 of Set 8 | wad madani
# Processing Record 19 of Set 8 | college
# Processing Record 20 of Set 8 | leshukonskoye
# Processing Record 21 of Set 8 | roald
# Processing Record 22 of Set 8 | novolvovsk
# City not found. Skipping...
# Processing Record 23 of Set 8 | muros
# Processing Record 24 of Set 8 | hudson bay
# Processing Record 25 of Set 8 | maningrida
# Processing Record 26 of Set 8 | kaitangata
# Processing Record 27 of Set 8 | gimli
# Processing Record 28 of Set 8 | caucaia
# Processing Record 29 of Set 8 | touros
# Processing Record 30 of Set 8 | havelock
# Processing Record 31 of Set 8 | kuvshinovo
# Processing Record 32 of Set 8 | tautira
# Processing Record 33 of Set 8 | tiarei
# Processing Record 34 of Set 8 | road town
# Processing Record 35 of Set 8 | santa cruz
# Processing Record 36 of Set 8 | general roca
# Processing Record 37 of Set 8 | san carlos de bariloche
# Processing Record 38 of Set 8 | ossora
# Processing Record 39 of Set 8 | vardo
# Processing Record 40 of Set 8 | valentin gomez farias
# Processing Record 41 of Set 8 | nizhniy baskunchak
# Processing Record 42 of Set 8 | aquiraz
# Processing Record 43 of Set 8 | constitucion
# Processing Record 44 of Set 8 | pozo colorado
# Processing Record 45 of Set 8 | arcata
# Processing Record 46 of Set 8 | andenes
# Processing Record 47 of Set 8 | kaeo
# Processing Record 48 of Set 8 | ilulissat
# Processing Record 49 of Set 8 | cayenne
# Processing Record 0 of Set 9 | boca do acre
# Processing Record 1 of Set 9 | anadyr
# Processing Record 2 of Set 9 | kutum
# Processing Record 3 of Set 9 | mizdah
# Processing Record 4 of Set 9 | ibra
# Processing Record 5 of Set 9 | jiaojiang
# Processing Record 6 of Set 9 | namatanai
# Processing Record 7 of Set 9 | norman wells
# Processing Record 8 of Set 9 | sharjah
# Processing Record 9 of Set 9 | palera
# Processing Record 10 of Set 9 | micheweni
# Processing Record 11 of Set 9 | riyadh
# Processing Record 12 of Set 9 | buala
# Processing Record 13 of Set 9 | sorland
# Processing Record 14 of Set 9 | altamira
# Processing Record 15 of Set 9 | san rafael
# Processing Record 16 of Set 9 | aspe
# Processing Record 17 of Set 9 | sabalgarh
# Processing Record 18 of Set 9 | arkhangelsk
# Processing Record 19 of Set 9 | labuan
# Processing Record 20 of Set 9 | katangli
# Processing Record 21 of Set 9 | antsla
# Processing Record 22 of Set 9 | beira
# Processing Record 23 of Set 9 | chivay
# Processing Record 24 of Set 9 | akyab
# Processing Record 25 of Set 9 | valverde del camino
# Processing Record 26 of Set 9 | menongue
# Processing Record 27 of Set 9 | uvat
# Processing Record 28 of Set 9 | salvador
# Processing Record 29 of Set 9 | kamenka
# Processing Record 30 of Set 9 | litovko
# Processing Record 31 of Set 9 | palana
# Processing Record 32 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 9 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 34 of Set 9 | adrar
# Processing Record 35 of Set 9 | ust-ilimsk
# Processing Record 36 of Set 9 | oromocto
# Processing Record 37 of Set 9 | progreso
# Processing Record 38 of Set 9 | wuan
# Processing Record 39 of Set 9 | sabana de torres
# Processing Record 40 of Set 9 | naryan-mar
# Processing Record 41 of Set 9 | rio muerto
# Processing Record 42 of Set 9 | papasquiaro
# City not found. Skipping...
# Processing Record 43 of Set 9 | mount pleasant
# Processing Record 44 of Set 9 | seminole
# Processing Record 45 of Set 9 | ust-nera
# Processing Record 46 of Set 9 | shingu
# Processing Record 47 of Set 9 | monopoli
# Processing Record 48 of Set 9 | kadoma
# Processing Record 49 of Set 9 | borovoy
# Processing Record 0 of Set 10 | kununurra
# Processing Record 1 of Set 10 | yecla
# Processing Record 2 of Set 10 | surgut
# Processing Record 3 of Set 10 | broadstairs
# Processing Record 4 of Set 10 | popondetta
# Processing Record 5 of Set 10 | marataizes
# Processing Record 6 of Set 10 | pipri
# Processing Record 7 of Set 10 | victoria
# Processing Record 8 of Set 10 | esperance
# Processing Record 9 of Set 10 | colotlan
# Processing Record 10 of Set 10 | rio gallegos
# Processing Record 11 of Set 10 | ghimes-faget
# Processing Record 12 of Set 10 | ouadda
# Processing Record 13 of Set 10 | gibsons
# Processing Record 14 of Set 10 | celestun
# Processing Record 15 of Set 10 | mogadishu
# Processing Record 16 of Set 10 | duiwelskloof
# Processing Record 17 of Set 10 | abu samrah
# Processing Record 18 of Set 10 | giyon
# Processing Record 19 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 10 | dutse
# Processing Record 21 of Set 10 | loknya
# Processing Record 22 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 10 | kahului
# Processing Record 24 of Set 10 | tondela
# Processing Record 25 of Set 10 | macas
# Processing Record 26 of Set 10 | severo-kurilsk
# Processing Record 27 of Set 10 | fukue
# Processing Record 28 of Set 10 | kloulklubed
# Processing Record 29 of Set 10 | nyagan
# Processing Record 30 of Set 10 | paucartambo
# City not found. Skipping...
# Processing Record 31 of Set 10 | taywarah
# Processing Record 32 of Set 10 | san cristobal
# Processing Record 33 of Set 10 | romanovka
# Processing Record 34 of Set 10 | saedinenie
# Processing Record 35 of Set 10 | emba
# Processing Record 36 of Set 10 | oktyabrskoye
# Processing Record 37 of Set 10 | jever
# Processing Record 38 of Set 10 | ibimirim
# Processing Record 39 of Set 10 | mountain home
# Processing Record 40 of Set 10 | yellandu
# Processing Record 41 of Set 10 | noumea
# Processing Record 42 of Set 10 | uray
# Processing Record 43 of Set 10 | buchanan
# Processing Record 44 of Set 10 | paso de carrasco
# Processing Record 45 of Set 10 | hereford
# Processing Record 46 of Set 10 | bar harbor
# Processing Record 47 of Set 10 | teacapan
# Processing Record 48 of Set 10 | shelburne
# Processing Record 49 of Set 10 | awjilah
# Processing Record 0 of Set 11 | finschhafen
# Processing Record 1 of Set 11 | vao
# Processing Record 2 of Set 11 | yasothon
# Processing Record 3 of Set 11 | riohacha
# Processing Record 4 of Set 11 | dryden
# Processing Record 5 of Set 11 | karangampel
# Processing Record 6 of Set 11 | cockburn town
# Processing Record 7 of Set 11 | hambantota
# Processing Record 8 of Set 11 | srandakan
# Processing Record 9 of Set 11 | kargasok
# Processing Record 10 of Set 11 | vostok
# Processing Record 11 of Set 11 | mackay
# Processing Record 12 of Set 11 | idaho falls
# Processing Record 13 of Set 11 | jacareacanga
# Processing Record 14 of Set 11 | awka
# Processing Record 15 of Set 11 | amarpur
# Processing Record 16 of Set 11 | manaure
# Processing Record 17 of Set 11 | bestobe
# Processing Record 18 of Set 11 | yumen
# Processing Record 19 of Set 11 | huilong
# Processing Record 20 of Set 11 | tamworth
# Processing Record 21 of Set 11 | sivaki
# Processing Record 22 of Set 11 | asyut
# Processing Record 23 of Set 11 | eyl
# Processing Record 24 of Set 11 | junin
# Processing Record 25 of Set 11 | sivas
# Processing Record 26 of Set 11 | ugoofaaru
# Processing Record 27 of Set 11 | havoysund
# Processing Record 28 of Set 11 | leeds
# Processing Record 29 of Set 11 | sheridan
# Processing Record 30 of Set 11 | thessalon
# Processing Record 31 of Set 11 | huron
# Processing Record 32 of Set 11 | filadelfia
# Processing Record 33 of Set 11 | klaksvik
# Processing Record 34 of Set 11 | maibong
# Processing Record 35 of Set 11 | raahe
# Processing Record 36 of Set 11 | lompoc
# Processing Record 37 of Set 11 | kurilsk
# Processing Record 38 of Set 11 | liwale
# Processing Record 39 of Set 11 | isiro
# Processing Record 40 of Set 11 | collie
# Processing Record 41 of Set 11 | berlevag
# Processing Record 42 of Set 11 | nsanje
# Processing Record 43 of Set 11 | durant
# Processing Record 44 of Set 11 | vila franca do campo
# Processing Record 45 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 11 | faya
# Processing Record 47 of Set 11 | norrtalje
# Processing Record 48 of Set 11 | garissa
# Processing Record 49 of Set 11 | tabou
# Processing Record 0 of Set 12 | shalakusha
# Processing Record 1 of Set 12 | kizukuri
# Processing Record 2 of Set 12 | magadan
# Processing Record 3 of Set 12 | lyubech
# Processing Record 4 of Set 12 | dzilam gonzalez
# Processing Record 5 of Set 12 | sao miguel
# Processing Record 6 of Set 12 | ilo
# Processing Record 7 of Set 12 | pokaran
# Processing Record 8 of Set 12 | remedios
# Processing Record 9 of Set 12 | samarai
# Processing Record 10 of Set 12 | northam
# Processing Record 11 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 12 | pingliang
# Processing Record 14 of Set 12 | ayios matthaios
# City not found. Skipping...
# Processing Record 15 of Set 12 | lar
# Processing Record 16 of Set 12 | west wendover
# Processing Record 17 of Set 12 | haines junction
# Processing Record 18 of Set 12 | yatou
# Processing Record 19 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 12 | redlands
# Processing Record 21 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 22 of Set 12 | mehamn
# Processing Record 23 of Set 12 | aitape
# Processing Record 24 of Set 12 | parrita
# Processing Record 25 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 26 of Set 12 | patiya
# Processing Record 27 of Set 12 | manta
# Processing Record 28 of Set 12 | lagoa
# Processing Record 29 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 30 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 31 of Set 12 | hami
# Processing Record 32 of Set 12 | coihaique
# Processing Record 33 of Set 12 | mednogorsk
# Processing Record 34 of Set 12 | balclutha
# Processing Record 35 of Set 12 | berbera
# Processing Record 36 of Set 12 | pundaguitan
# Processing Record 37 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 12 | kota bahru
# Processing Record 39 of Set 12 | gazli
# Processing Record 40 of Set 12 | pishin
# Processing Record 41 of Set 12 | koubia
# Processing Record 42 of Set 12 | laguna
# Processing Record 43 of Set 12 | lake cowichan
# Processing Record 44 of Set 12 | koumac
# Processing Record 45 of Set 12 | boke
# Processing Record 46 of Set 12 | comodoro rivadavia
# Processing Record 47 of Set 12 | boyolangu
# Processing Record 48 of Set 12 | grand gaube
# Processing Record 49 of Set 12 | hessisch oldendorf
# Processing Record 0 of Set 13 | banjar
# Processing Record 1 of Set 13 | nantucket
# Processing Record 2 of Set 13 | bonavista
# Processing Record 3 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 13 | oprisor
# Processing Record 5 of Set 13 | seoul
# Processing Record 6 of Set 13 | fereydunshahr
# Processing Record 7 of Set 13 | wanning
# Processing Record 8 of Set 13 | proletariy
# Processing Record 9 of Set 13 | huanren
# Processing Record 10 of Set 13 | dicabisagan
# Processing Record 11 of Set 13 | porto novo
# Processing Record 12 of Set 13 | udachnyy
# Processing Record 13 of Set 13 | kandrian
# Processing Record 14 of Set 13 | bac
# Processing Record 15 of Set 13 | pilibanga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       ushuaia -54.8000  -68.3000      0.81        80          75
# 1     jamestown  42.0970  -79.2353      1.80        74           0
# 2      semporna   4.4818  118.6112     28.45        70         100
# 3      tasiilaq  65.6145  -37.6368    -18.17        65           1
# 4    lavrentiya  65.5833 -171.0000     -4.37        96         100
# ..          ...      ...       ...       ...       ...         ...
# 561  porto novo   6.4965    2.6036     26.72        85          84
# 562    udachnyy  66.4167  112.4000    -18.33        86         100
# 563    kandrian  -6.2167  149.5500     28.97        73          44
# 564         bac  45.3919   19.2367      0.00        74          35
# 565   pilibanga  29.4916   74.0790     25.54        30          99
#
#      Wind Speed Country        Date
# 0          3.09      AR  1680058688
# 1          0.89      US  1680058434
# 2          4.00      MY  1680058688
# 3          3.39      GL  1680058688
# 4          6.65      RU  1680058392
# ..          ...     ...         ...
# 561        2.14      BJ  1680058897
# 562        1.42      RU  1680058897
# 563        3.44      PG  1680058898
# 564        3.23      RS  1680058898
# 565        5.06      IN  1680058882
#
# [566 rows x 9 columns]

# %%
# Export the City_Data into a csv
city_data_df.to_csv("Untitled Folder/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("Untitled Folder/cities.csv", index_col="City_ID")

# Display sample data
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           ushuaia -54.8000  -68.3000      0.81        80          75
# 1         jamestown  42.0970  -79.2353      1.80        74           0
# 2          semporna   4.4818  118.6112     28.45        70         100
# 3          tasiilaq  65.6145  -37.6368    -18.17        65           1
# 4        lavrentiya  65.5833 -171.0000     -4.37        96         100
# ...             ...      ...       ...       ...       ...         ...
# 561      porto novo   6.4965    2.6036     26.72        85          84
# 562        udachnyy  66.4167  112.4000    -18.33        86         100
# 563        kandrian  -6.2167  149.5500     28.97        73          44
# 564             bac  45.3919   19.2367      0.00        74          35
# 565       pilibanga  29.4916   74.0790     25.54        30          99
#
#          Wind Speed Country        Date
# City_ID
# 0              3.09      AR  1680058688
# 1              0.89      US  1680058434
# 2              4.00      MY  1680058688
# 3              3.39      GL  1680058688
# 4              6.65      RU  1680058392
# ...             ...     ...         ...
# 561            2.14      BJ  1680058897
# 562            1.42      RU  1680058897
# 563            3.44      PG  1680058898
# 564            3.23      RS  1680058898
# 565            5.06      IN  1680058882
#
# [566 rows x 9 columns]

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title('City Max Latitude vs. Temperature(2022-10-18)')
plt.grid()
# Save the figure
plt.savefig("Untitled Folder/Fig1.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title('City Max Latitude vs. Humidity(2022-10-18)')
plt.grid()
# Save the figure
plt.savefig("Untitled Folder/Fig2.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title('City Max Latitude vs. Cloudiness(2022-10-18)')
plt.grid()
# Save the figure
plt.savefig("Untitled Folder/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title('City Max Latitude vs. Wind Speed(2022-10-18)')
plt.grid()
# Save the figure
plt.savefig("Untitled Folder/Fig4.png")
# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# # Perform a linear regression on temperature vs. latitude
# (slope, intercept, rvalue, pvalue, stderr) = linregress(weather_data["lat"], weather_data["temp"])
# # Get regression values
# regress_values = slope * weather_data["lat"] + intercept
# # Create line equation string
# line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
# print(line_eq)
# # Label plot and annotate the line equation
# plt.annotate(line_eq, (20, 5), color='red')
# # Print r square value
# print(rvalue**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4384\760224360.py in <module>
#       1 # Perform a linear regression on temperature vs. latitude
# ----> 2 (slope, intercept, rvalue, pvalue, stderr) = linregress(weather_data["lat"], weather_data["temp"])
#       3 # Get regression values
#       4 regress_values = slope * weather_data["lat"] + intercept
#       5 # Create line equation string
#
# NameError: name 'weather_data' is not defined

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0), :]
# Northern Hemisphere (greater than or equal to 0 degrees latitude)
# Display sample data
northern_hemi_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1   jamestown  42.0970  -79.2353      1.80        74           0        0.89
# 2    semporna   4.4818  118.6112     28.45        70         100        4.00
# 3    tasiilaq  65.6145  -37.6368    -18.17        65           1        3.39
# 4  lavrentiya  65.5833 -171.0000     -4.37        96         100        6.65
# 9       tiksi  71.6872  128.8694    -21.71        86          99        4.69
#
#   Country        Date
# 1      US  1680058434
# 2      MY  1680058688
# 3      GL  1680058688
# 4      RU  1680058392
# 9      RU  1680058690

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0), :]
# Display sample data
southern_hemi_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     ushuaia -54.8000  -68.3000      0.81        80          75        3.09
# 5       bluff -46.6000  168.3333     10.45        57          75        6.76
# 6       vaini -21.2000 -175.2000     29.09        84          40        3.60
# 7     ahipara -35.1667  173.1667     17.29        47          28        7.70
# 8  nelson bay -32.7167  152.1500     28.94        66          59        2.60
#
#   Country        Date
# 0      AR  1680058688
# 5      NZ  1680058689
# 6      TO  1680058689
# 7      NZ  1680058690
# 8      AU  1680058690

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
